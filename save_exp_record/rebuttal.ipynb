# %% [markdown]
# # unit test KDD
#
# "gcn", "jaccard_gcn", "svd_gcn", "rgcn", "pro_gnn", "gnn_guard", "grand", "soft_median_gdc"
#
# Citeseer   hidden 64 因为我们发现扰动情况下hidden小一下效果更好
#                  svd_gcn               grand               gnn_guard            jaccard_gcn
# GraphMAE   0     0.7687±0.0027         0.4775±0.0273       0.6718±0.0089        0.6345±0.0148
#            1
#            2
#            3
#            4
#
# GraphMAE2  0     0.7716±0.0021         0.4825±0.0281       0.6662±0.0050        0.6223±0.0121
#            1
#            2
#            3
#            4
#
#
# FilterMGAE 0     0.7675±0.0039         0.5672±0.0080       0.6863±0.0027        0.6623±0.0077
#            1
#            2
#            3
#            4
#
#
#
#
# Cora       hidden 64 因为我们发现扰动情况下hidden小一下效果更好
#                  svd_gcn               grand                gnn_guard              jaccard_gcn
# GraphMAE   0     0.8524±0.0018         0.4522±0.0337        0.6569±0.0055          0.8076±0.0018
#            1
#            2
#            3
#            4
#
# GraphMAE2  0    0.8493±0.0008          0.4238±0.0108        0.6227±0.0015          0.7988±0.0010
#            2
#            3
#            4
#
#
# FilterMGAE 0    0.8514±0.0015          0.5526±0.0083        0.7235±0.0075          0.8200±0.0015
#            1
#            2
#            3

# %% [markdown]
# # unit test ICDE
# 由于Unit test的攻击范围从2%-15%不等，包含大约2500个图，选择不同分类的代表性模型进行最大比例15%的自适应攻击, seed [1 , 2]
#
# "gcn", "jaccard_gcn", "svd_gcn", "rgcn", "pro_gnn", "gnn_guard", "grand", "soft_median_gdc"
#
# Cora-ML    hidden 64 因为我们发现扰动情况下hidden小一下效果更好
#                  svd_gcn               grand               gnn_guard            jaccard_gcn
# GraphMAE   0     0.8332±0.0043         0.4492±0.0347       0.6587±0.0018        0.6195±0.0103
#            1     0.8177±0.0003         0.4122±0.0053       0.6977±0.0101        0.6006±0.0080
#            2     0.8312±0.0008         0.4147±0.0083       0.6713±0.0068        0.5523±0.0035
#            3     0.8255±0.0030         0.5030±0.0020       0.7088±0.0015        0.6383±0.0060
#            4     0.8441±0.0015         0.3260±0.0080       0.5656±0.0008        0.5493±0.0216
#
# GraphMAE2  0     0.8335±0.0005         0.4228±0.0018       0.6222±0.0010        0.6127±0.0030
#            1     0.8164±0.0060         0.4004±0.0111       0.6358±0.0040        0.5905±0.0091
#            2     0.8290±0.0075         0.3891±0.0053       0.6041±0.0010        0.5362±0.0096
#            3     0.8202±0.0033         0.4623±0.0086       0.6698±0.0058        0.6044±0.0158
#            4     0.8408±0.0013         0.3212±0.0003       0.5370±0.0028        0.5453±0.0091
#
#
# FilterMGAE 0
#            1
#            2
#            3                           0.5687±0.0033       0.7515±0.0053        0.6750±0.0150
#            4    0.8410±0.0015
#
#
#
#
# Citeseer    hidden 64 因为我们发现扰动情况下hidden小一下效果更好
#                  svd_gcn               grand                gnn_guard              jaccard_gcn
# GraphMAE   0     0.7562±0.0003         0.4745±0.0314        0.6762±0.0080          0.6392±0.0255
#            1     0.7556±0.0050         0.4076±0.0124        0.6413±0.0104          0.6143±0.0053
#            2     0.7444±0.0062         0.5121±0.0121        0.6217±0.0086          0.5915±0.0104
#            3     0.7399±0.0006         0.5912±0.0047        0.6721±0.0009          0.6303±0.0024
#            4     0.7213±0.0009         0.4730±0.0062        0.6404±0.0024          0.6286±0.0000
#
# GraphMAE2  0     0.7550±0.0044         0.4884±0.0341        0.6626±0.0080          0.6238±0.0101
#            1     0.7536±0.0059         0.4570±0.0062        0.6460±0.0133          0.6046±0.0003
#            2     0.7361±0.0056         0.5089±0.0065        0.6197±0.0036          0.5930±0.0012
#            3     0.7408±0.0003         0.5773±0.0068        0.6751±0.0044          0.6443±0.0068
#            4     0.7195±0.0003         0.5056±0.0157        0.6434±0.0035          0.6283±0.0157
#
#
# FilterMGAE 0     0.7509±0.0015                                                     0.6623±0.0077
#            1
#            2
#            3                           0.6887±0.0074        0.6863±0.0027
#            4

# %% [markdown]
# # 小扰动攻击 按照审稿人的要求 cora meta self
#                   GraphMAE            GraphMAE2          FilterMGAE
# 0.5% 25条边       0.8501±0.0050       0.8519±0.0058      0.8506±0.0049
# 1%,  50条边       0.8463±0.0073       0.8453±0.0068      0.8473±0.0035
# 3%,  152条边      0.8358±0.0068       0.8287±0.0043      0.8330±0.0005
# 5%,  253条边      0.8014±0.0059       0.8154±0.0055      0.8202±0.0003
# 10%  506条边      0.7241±0.0118       0.6788±0.0088      0.7462±0.0008
# 15%  759条边      0.6522±0.0034       0.6107±0.0075      0.7183±0.0026
# 20%  1012条边     0.5780±0.0151       0.5020±0.0070      0.6761±0.0053

# %% [markdown]
# # GARNET 比较     只能200个epoch, epoch多了会很差, 200个左右是最好的效果，garnet太不适合作为被重建目标
# Cora       G-GARNET             Ours
# 0%         0.7975±0.0078        0.8576±0.0025
# 15%        0.6708±0.0053        0.7233±0.0043
# 25%        0.5460±0.0043        0.6212±0.0014
#
# # 只能100个epoch 但训练目标不对
# Cora ML     G-GARNET             Ours
# 0%          0.7255±0.0018        0.8692±0.0035
# 15%         0.5033±0.0087        0.7891±0.0065
# 25%         0.4133±0.0076        0.6489±0.0078
